# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_excel(r"C:/Users/Aboubakr Ben Bach/Desktop/ML/dataset.xlsx")
data1 = pd.read_excel(r"C:/Users/Aboubakr Ben Bach/Desktop/ML/titanic3.xlsx")

# %%
data.shape
data.head()
# Out:
#    LOSN  LOD          LOA  NOFG  NOFR     DOUNIDF      FLFR   TNTS      NOTSD  \
# 0     8  132  1217.812905  3269  3071  190.948990  1.064474    861   4.000000
# 1     9  134  1329.539931  1949   793   11.410954  2.457755    226   2.224719
# 2    12  158  1272.640301  1119  9644  859.883181  0.116031  38674  49.250000
# 3    11  121  1105.971852  2174  6029  284.380430  0.360590  12718  10.526316
# 4     6   70  1105.341435  7731  7029  113.779674  1.099872    873   9.523810
#
#          TLA    TURLTW      ANUT   Mention      MeanTBT        MaxTBT  Class
# 0   0.707477  0.163763  0.705000  0.078978   492.219765   4416.416667      1
# 1   0.169925  0.575221  0.656566  0.261062  3312.557196  93332.016670      1
# 2  30.380204  0.001370  0.269036  0.002870    28.432738    730.966667      1
# 3  11.499096  0.005032  0.320000  0.007155   125.861139   1247.166667      1
# 4   0.789331  0.158076  0.690000  0.024055   218.854020   5906.033333      1

# %%
#pour supprimer les colonnes qui nous ont inutiles
data1 = data1.drop(['name','sibsp','parch','ticket','fare','cabin','embarked','boat','body','home.dest'], axis=1)

# %%
data1.head()
# Out:
#    pclass  survived     sex      age
# 0       1         1  female  29.0000
# 1       1         1    male   0.9167
# 2       1         0  female   2.0000
# 3       1         0    male  30.0000
# 4       1         0  female  25.0000

# %%
#####on veut convertir category en numerique
#data1['sex'].map({'male':1, 'female':0})
#deuxième methode
#data1['sex'].replace(['male','female'],[0,1])
#troisième methode
data1['sex'].astype('category').cat.codes
# Out:
# 0       0
# 1       1
# 2       0
# 3       1
# 4       0
#        ..
# 1301    1
# 1304    0
# 1306    1
# 1307    1
# 1308    1
# Length: 1046, dtype: int8

# %%
data1.head()
"""data1.describe()
#on va supprimer toutes les lignes ayant des valeurs manquantes
data1= data1.dropna(axis=0)
data1.shape
data1.describe()"""
# Out:
#    pclass  survived     sex      age
# 0       1         1  female  29.0000
# 1       1         1    male   0.9167
# 2       1         0  female   2.0000
# 3       1         0    male  30.0000
# 4       1         0  female  25.0000

# %%
#pour connaitres le nombre de personne qui sont en 1ere, deuxième et troisième classe
data1['pclass'].value_counts()
data1['pclass'].value_counts().plot.bar()

# %%
data1['age'].hist()

# %%
data1.groupby(['sex','pclass']).mean()
# Out:
#                survived        age
# sex    pclass
# female 1       0.962406  37.037594
#        2       0.893204  27.499191
#        3       0.473684  22.185307
# male   1       0.350993  41.029250
#        2       0.145570  30.815401
#        3       0.169054  25.962273

# %% [markdown]
# ##### data1= data1.set_index('index')#: si on veut indexer selon notre propre index
# #data1['age']
#
#
# # 10 premieres valeurs de notre 'Series' age
# data1['age'][0:10]
#
# #booleing
# data1[data1['age'] <18]['pclass'].value_counts

# %%
#booleing
data1[data1['age'] <18]['pclass'].value_counts()
#group by
data1[data1['age'] <18].groupby(['sex','pclass']).mean()
# Out:
#                survived        age
# sex    pclass
# female 1       0.875000  14.125000
#        2       1.000000   8.273150
#        3       0.543478   8.416667
# male   1       0.857143   9.845243
#        2       0.733333   6.222220
#        3       0.233333   9.838888

# %%
#indexing dans pandas
data1.iloc[0:5,0::]
# Out:
#    pclass  survived     sex      age
# 0       1         1  female  29.0000
# 1       1         1    male   0.9167
# 2       1         0  female   2.0000
# 3       1         0    male  30.0000
# 4       1         0  female  25.0000

# %%
#indexing selon les colonnes
data1.loc[0::, ['age','sex']]
# Out:
#           age     sex
# 0     29.0000  female
# 1      0.9167    male
# 2      2.0000  female
# 3     30.0000    male
# 4     25.0000  female
# ...       ...     ...
# 1301  45.5000    male
# 1304  14.5000  female
# 1306  26.5000    male
# 1307  27.0000    male
# 1308  29.0000    male
#
# [1046 rows x 2 columns]

# %%
import seaborn as sns
df3 = pd.read_csv(r"C:/Users/Aboubakr Ben Bach/Desktop/ML/Iris.csv")

# %%
df3.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.pairplot(df3)

# %%
sns.pairplot(df3, hue='Species')
